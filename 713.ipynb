# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from transformers import pipeline
pipe = pipeline("text-generation", model="openai-community/gpt2")
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]

# %%
# from transformers import AutoTokenizer, AutoModelForCausalLM
from transformers import GPT2Tokenizer, GPT2Model

tokenizer = GPT2Tokenizer.from_pretrained("openai-community/gpt2")
model = GPT2Model.from_pretrained("openai-community/gpt2")

text = "Why doesn't windows task manager show correct total RAM usage?"
encoded_input = tokenizer(text, return_tensors='pt')
output = model(**encoded_input)
output
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# BaseModelOutputWithPastAndCrossAttentions(last_hidden_state=tensor([[[-0.0493,  0.0915, -0.3144,  ..., -0.2790, -0.0043, -0.1121],
#          [-0.0856,  0.1868, -0.2463,  ..., -0.3988, -0.5193,  0.0976],
#          [ 0.3289,  0.1108,  0.3533,  ..., -0.3247,  0.0054, -0.2481],
#          ...,
#          [-0.0175, -0.2992, -0.9431,  ...,  0.0856, -0.1723, -0.1245],
#          [-0.1386,  0.2679, -1.6859,  ..., -0.0772, -0.3408, -0.3836],
#          [ 0.2303, -0.1567, -0.1441,  ...,  0.1907, -0.0483, -0.4096]]],
#        grad_fn=<ViewBackward0>), past_key_values=DynamicCache(layers=[DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer]), hidden_states=None, attentions=None, cross_attentions=None)

# %%
from transformers import set_seed
set_seed(42)
pipe("Messi or Ronaldo?", max_length=30, num_return_sequences=5)
# Out:
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': "Messi or Ronaldo?\n\nThe best way to think about it, and I think the best way to think about it is that one of the reasons the game is so complicated is because it's kind of hard to understand.\n\nIt's hard to understand how to play it. You have to play it to get a win. It's hard. It's hard to understand how to play it, because you have to play it to get a win. It's hard to understand what they're trying to do.\n\nWhen you look at a video game, it's hard to understand how to play it. You have to play it to get a win. It's hard. It's hard to understand.\n\nAnd it's hard to understand how to play it, because you have to play it because you have to play it.\n\nAnd it's hard to understand.\n\nYou have to play it because you have to play it. It's hard. It's hard to understand.\n\nIt's hard to understand.\n\nIt's hard to understand.\n\nIt's hard to understand. The moment you play it, you have to play it because you have to play it because you have to play it.\n\nWhen you play it, you have"},
#  {'generated_text': 'Messi or Ronaldo?\n\nThe answer is always the same.\n\nThe Real Madrid man has played for the club since 2005, and has worked with them as a member of the Champions League team.\n\nThe fact that he has played for the club since then has been a big boost to his confidence.\n\nThe Portuguese has had a tough time playing at Madrid – he has been sacked after two seasons and has to deal with a difficult spell in the Spanish Premier League.\n\nBut the move to Paris Saint-Germain was something that was never a serious problem for him.\n\nThere